# %%
# Dependencies and Setup
from datetime import datetime
import pandas as pd
import numpy as np
import os
import requests
import json
from pprint import pprint
from dotenv import load_dotenv

# %%
# API Call
load_dotenv()
API_KEY = os.getenv("Yelp_API") # put your key here if you don't have a .env file in your main project folder.
headers = {'Authorization': 'Bearer %s' % API_KEY}
base_url = "https://api.yelp.com/v3/businesses/search"

# %%
# Stadiums/Arenas data folder
dataFolder='stadiums_data'

# %%
def createFolder(outFolder):
    # Creates directory for current day of the week, raises an error if already exists.
    parent_dir = 'json_files'
    # output_dir = f'{day_of_the_week}1000'
    path = os.path.join(parent_dir, outFolder)
    try:
        os.mkdir(path)
    except:
        print('Folder already exists.')
        
    return path

# %%
def League(path=dataFolder):
    today = datetime.today()
    liga=input("Input value:\nNFL, NBA, MLB, MLS, NHL: ")
    filename=f'{liga}.csv'
    filepath=os.path.join(path,filename)
    df=pd.read_csv(filepath, encoding='utf-8', dtype={"Team": "string", "City": "string", "State": "string", "Stadium Name": "string", 
                                    "Latitude": np.float64, "Longitude": np.float64})
    outputFolder=f'{liga}_{today.day}_{today.month}_{today.year}_{today.hour}h{today.minute}m'
    output_path=createFolder(outputFolder)
    return df, output_path

# %%
stadium_df, outpath=League()
# Out:
# Input value:
# NFL, NBA, MLB, MLS, NHL: NHL

# %%
stadium_df
# Out:
#                      Team          City             State  \
# 0     Tampa Bay Lightning         Tampa           Florida
# 1            Dallas Stars        Dallas             Texas
# 2      Colorado Avalanche        Denver          Colorado
# 3        Florida Panthers       Sunrise           Florida
# 4      Montreal Canadiens      Montreal            Quebec
# 5           Winnipeg Jets      Winnipeg          Manitoba
# 6     Nashville Predators     Nashville         Tennessee
# 7         Ottawa Senators        Ottawa           Ontario
# 8     Washington Capitals    Washington              D.C.
# 9         St. Louis Blues     St. Louis          Missouri
# 10        Arizona Coyotes      Glendale           Arizona
# 11          Anaheim Ducks       Anaheim        California
# 12         Buffalo Sabres       Buffalo          New York
# 13      Detroit Red Wings       Detroit          Michigan
# 14       New York Rangers      New York          New York
# 15     New York Islanders     Uniondale          New York
# 16  Columbus Blue Jackets      Columbus              Ohio
# 17    Carolina Hurricanes       Raleigh    North Carolina
# 18    Pittsburgh Penguins    Pittsburgh      Pennsylvania
# 19      New Jersey Devils        Newark        New Jersey
# 20      Vancouver Canucks     Vancouver  British Columbia
# 21        Edmonton Oilers      Edmonton           Alberta
# 22    Toronto Maple Leafs       Toronto           Ontario
# 23         Calgary Flames       Calgary           Alberta
# 24        San Jose Sharks      San Jose        California
# 25      Los Angeles Kings   Los Angeles        California
# 26          Boston Bruins        Boston     Massachusetts
# 27   Vegas Golden Knights      Paradise            Nevada
# 28     Chicago Blackhawks       Chicago          Illinois
# 29    Philadelphia Flyers  Philadelphia      Pennsylvania
# 30         Minnesota Wild    Saint Paul         Minnesota
#
#                 Stadium Name   Latitude   Longitude
# 0               Amalie Arena  27.942824  -82.451785
# 1   American Airlines Center  32.790556  -96.810278
# 2                 Ball Arena  39.748837 -105.007613
# 3                BB&T Center  26.158333  -80.325556
# 4                Bell Centre  45.496111  -73.569444
# 5             Bell MTS Place  49.892778  -97.143611
# 6          Bridgestone Arena  36.159167  -86.778611
# 7       Canadian Tire Centre  45.297049  -75.926838
# 8          Capital One Arena  38.898690  -77.020843
# 9          Enterprise Center  38.626667  -90.202500
# 10          Gila River Arena  33.532269 -112.261280
# 11              Honda Center  33.807778 -117.876667
# 12            KeyBank Center  42.875000  -78.876389
# 13      Little Caesars Arena  42.341111  -83.055000
# 14     Madison Square Garden  40.750556  -73.993611
# 15           Nassau Coliseum  40.722778  -73.590556
# 16          Nationwide Arena  39.969283  -83.006111
# 17                 PNC Arena  35.803333  -78.721944
# 18          PPG Paints Arena  40.439444  -79.989167
# 19         Prudential Center  40.733611  -74.171111
# 20              Rogers Arena  49.277778 -123.108889
# 21              Rogers Place  53.546944 -113.497778
# 22          Scotiabank Arena  43.643652  -79.379077
# 23     Scotiabank Saddledome  51.037946 -114.052019
# 24                SAP Center  37.332778 -121.901110
# 25            Staples Center  34.043056 -118.267222
# 26                 TD Garden  42.366303  -71.062228
# 27            T-Mobile Arena  36.102778 -115.178333
# 28             United Center  41.880556  -87.674167
# 29        Wells Fargo Center  39.901111  -75.171944
# 30        Xcel Energy Center  44.944722  -93.101111

# %%
def teamLoc(df):
    zipi=zip(df["Latitude"], df["Longitude"], df["Team"])
    return list(zipi)

# %%
stadium=teamLoc(stadium_df)

# %%
stadium
# Out:
# [(27.942823999999998, -82.451785, 'Tampa Bay Lightning'),
#  (32.790556, -96.810278, 'Dallas Stars'),
#  (39.748837, -105.00761299999999, 'Colorado Avalanche'),
#  (26.158333, -80.325556, 'Florida Panthers'),
#  (45.496111, -73.56944399999999, 'Montreal Canadiens'),
#  (49.892778, -97.14361099999999, 'Winnipeg Jets'),
#  (36.159167, -86.778611, 'Nashville Predators'),
#  (45.2970495, -75.92683790000001, 'Ottawa Senators'),
#  (38.89869, -77.020843, 'Washington Capitals'),
#  (38.626667, -90.2025, 'St. Louis Blues'),
#  (33.532269, -112.26128, 'Arizona Coyotes'),
#  (33.807778000000006, -117.876667, 'Anaheim Ducks'),
#  (42.875, -78.876389, 'Buffalo Sabres'),
#  (42.341111, -83.055, 'Detroit Red Wings'),
#  (40.750556, -73.993611, 'New York Rangers'),
#  (40.722778000000005, -73.590556, 'New York Islanders'),
#  (39.969283000000004, -83.006111, 'Columbus Blue Jackets'),
#  (35.803333, -78.721944, 'Carolina Hurricanes'),
#  (40.439444, -79.98916700000001, 'Pittsburgh Penguins'),
#  (40.733610999999996, -74.171111, 'New Jersey Devils'),
#  (49.277778000000005, -123.10888899999999, 'Vancouver Canucks'),
#  (53.546943999999996, -113.497778, 'Edmonton Oilers'),
#  (43.643652, -79.379077, 'Toronto Maple Leafs'),
#  (51.037946000000005, -114.052019, 'Calgary Flames'),
#  (37.332778000000005, -121.90111, 'San Jose Sharks'),
#  (34.043056, -118.267222, 'Los Angeles Kings'),
#  (42.366303, -71.062228, 'Boston Bruins'),
#  (36.102778, -115.17833300000001, 'Vegas Golden Knights'),
#  (41.880556, -87.67416700000001, 'Chicago Blackhawks'),
#  (39.901111, -75.171944, 'Philadelphia Flyers'),
#  (44.944722, -93.101111, 'Minnesota Wild')]

# %%
# Function to download the JSON files
def downloadJSON(lista, term, radius, path):
    count_f = 0
    # API parameters
    search_params = {"term": term, "limit": 20, "radius": radius, "sort_by": "rating"}
    class Exception_1(Exception):
        """ Raised if "total" is not found in the request """
        pass
    for latitude, longitude, team in lista:

        search_params.update({"latitude": latitude, "longitude": longitude})
        response = requests.get(url = base_url, params = search_params, headers = headers).json()
        try:

            if response['total']== False:
                raise Exception_1
            elif response['total'] >= 1000:
                total = 1000
            else:
                total = response['total']

            for search_offset in range(0, total, 20):

                search_params.update({"offset": search_offset})
                response2 = requests.get(url = base_url, params = search_params, headers = headers).json()
                file_name = f'yelp_response_{team}_{search_offset}.json'
                output_path = os.path.join(path, file_name)

                with open(output_path,'w', encoding = 'utf-8') as f:
                    json.dump(response2, f, ensure_ascii=False, indent =4)
                f.close()

        except Exception_1 as e:
            print("Error: 'total' not found.\nPlease try again later.")
            print(e)

        print(f'{count_f}, {team} total: {total}')

        count_f += 1

# %%
downloadJSON(stadium, "restaurants", 3000, outpath)
# Out:
# 0, Tampa Bay Lightning total: 328
# 1, Dallas Stars total: 755
# 2, Colorado Avalanche total: 850
# 3, Florida Panthers total: 97
# 4, Montreal Canadiens total: 1000
# 5, Winnipeg Jets total: 418
# 6, Nashville Predators total: 662
# 7, Ottawa Senators total: 84
# 8, Washington Capitals total: 1000
# 9, St. Louis Blues total: 303
# 10, Arizona Coyotes total: 102
# 11, Anaheim Ducks total: 327
# 12, Buffalo Sabres total: 241
# 13, Detroit Red Wings total: 513
# 14, New York Rangers total: 1000
# 15, New York Islanders total: 282
# 16, Columbus Blue Jackets total: 528
# 17, Carolina Hurricanes total: 73
# 18, Pittsburgh Penguins total: 610
# 19, New Jersey Devils total: 562
# 20, Vancouver Canucks total: 1000
# 21, Edmonton Oilers total: 605
# 22, Toronto Maple Leafs total: 1000
# 23, Calgary Flames total: 728
# 24, San Jose Sharks total: 590
# 25, Los Angeles Kings total: 1000
# 26, Boston Bruins total: 1000
# 27, Vegas Golden Knights total: 1000
# 28, Chicago Blackhawks total: 956
# 29, Philadelphia Flyers total: 288
# 30, Minnesota Wild total: 299

# %% [markdown]
# ## Check json files integrity
# Sometimes, due to an internal error in Yelp, the YELP API would return an empty file with an error code in it.
#
# Print to terminal if the json file has errors or not.
#
# If there are files with errors, the above request data needs to be re-run.

# %%
def JSONcheck(jsonpath):
    files_list = os.listdir(jsonpath)
    error_list = []
    for file in files_list:
        open_path = os.path.join(jsonpath, file)
        with open(open_path, 'r', encoding = 'utf-8') as f:
            contents = json.loads(f.read())
            try:
                total = contents['total']
            except:
                print(f"INTERNAL_ERROR in {file}")
                print("Something went wrong internally, please try downloading the json file again later.\n")
                file = f'{file}'
                error_list.append(file)
            else:
                print(f'\nNo errors found in the json file:\n{file}\n')
        
    if not error_list:
        print(f'No erros in json files.\nNo files to be removed for the analysis.')
    else:
        print(f'Files with errors:\n{error_list}')
    return error_list

# %%
error_list = JSONcheck(outpath)
# Out:
# No errors found in the json file:
# yelp_response_Anaheim Ducks_0.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_100.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_120.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_140.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_160.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_180.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_20.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_200.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_220.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_240.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_260.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_280.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_300.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_320.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_40.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_60.json
#
#
# No errors found in the json file:
# yelp_response_Anaheim Ducks_80.json
#
#
# No errors found in the json file:
# yelp_response_Arizona Coyotes_0.json
#
#
# No errors found in the json file:
# yelp_response_Arizona Coyotes_100.json
#
#
# No errors found in the json file:
# yelp_response_Arizona Coyotes_20.json
#
#
# No errors found in the json file:
# yelp_response_Arizona Coyotes_40.json
#
#
# No errors found in the json file:
# yelp_response_Arizona Coyotes_60.json
#
#
# No errors found in the json file:
# yelp_response_Arizona Coyotes_80.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_0.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_100.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_120.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_140.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_160.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_180.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_20.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_200.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_220.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_240.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_260.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_280.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_300.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_320.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_340.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_360.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_380.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_40.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_400.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_420.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_440.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_460.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_480.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_500.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_520.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_540.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_560.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_580.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_60.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_600.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_620.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_640.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_660.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_680.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_700.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_720.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_740.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_760.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_780.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_80.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_800.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_820.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_840.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_860.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_880.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_900.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_920.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_940.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_960.json
#
#
# No errors found in the json file:
# yelp_response_Boston Bruins_980.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_0.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_100.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_120.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_140.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_160.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_180.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_20.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_200.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_220.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_240.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_40.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_60.json
#
#
# No errors found in the json file:
# yelp_response_Buffalo Sabres_80.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_0.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_100.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_120.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_140.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_160.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_180.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_20.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_200.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_220.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_240.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_260.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_280.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_300.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_320.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_340.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_360.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_380.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_40.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_400.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_420.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_440.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_460.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_480.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_500.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_520.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_540.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_560.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_580.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_60.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_600.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_620.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_640.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_660.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_680.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_700.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_720.json
#
#
# No errors found in the json file:
# yelp_response_Calgary Flames_80.json
#
#
# No errors found in the json file:
# yelp_response_Carolina Hurricanes_0.json
#
#
# No errors found in the json file:
# yelp_response_Carolina Hurricanes_20.json
#
#
# No errors found in the json file:
# yelp_response_Carolina Hurricanes_40.json
#
#
# No errors found in the json file:
# yelp_response_Carolina Hurricanes_60.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_0.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_100.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_120.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_140.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_160.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_180.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_20.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_200.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_220.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_240.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_260.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_280.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_300.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_320.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_340.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_360.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_380.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_40.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_400.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_420.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_440.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_460.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_480.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_500.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_520.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_540.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_560.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_580.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_60.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_600.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_620.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_640.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_660.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_680.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_700.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_720.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_740.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_760.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_780.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_80.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_800.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_820.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_840.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_860.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_880.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_900.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_920.json
#
#
# No errors found in the json file:
# yelp_response_Chicago Blackhawks_940.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_0.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_100.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_120.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_140.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_160.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_180.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_20.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_200.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_220.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_240.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_260.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_280.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_300.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_320.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_340.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_360.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_380.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_40.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_400.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_420.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_440.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_460.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_480.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_500.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_520.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_540.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_560.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_580.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_60.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_600.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_620.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_640.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_660.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_680.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_700.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_720.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_740.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_760.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_780.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_80.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_800.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_820.json
#
#
# No errors found in the json file:
# yelp_response_Colorado Avalanche_840.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_0.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_100.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_120.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_140.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_160.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_180.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_20.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_200.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_220.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_240.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_260.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_280.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_300.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_320.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_340.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_360.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_380.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_40.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_400.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_420.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_440.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_460.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_480.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_500.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_520.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_60.json
#
#
# No errors found in the json file:
# yelp_response_Columbus Blue Jackets_80.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_0.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_100.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_120.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_140.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_160.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_180.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_20.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_200.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_220.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_240.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_260.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_280.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_300.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_320.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_340.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_360.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_380.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_40.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_400.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_420.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_440.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_460.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_480.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_500.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_520.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_540.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_560.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_580.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_60.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_600.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_620.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_640.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_660.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_680.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_700.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_720.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_740.json
#
#
# No errors found in the json file:
# yelp_response_Dallas Stars_80.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_0.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_100.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_120.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_140.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_160.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_180.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_20.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_200.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_220.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_240.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_260.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_280.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_300.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_320.json
# No errors found in the json file:
# yelp_response_Detroit Red Wings_340.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_360.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_380.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_40.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_400.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_420.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_440.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_460.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_480.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_500.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_60.json
#
#
# No errors found in the json file:
# yelp_response_Detroit Red Wings_80.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_0.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_100.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_120.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_140.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_160.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_180.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_20.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_200.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_220.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_240.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_260.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_280.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_300.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_320.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_340.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_360.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_380.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_40.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_400.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_420.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_440.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_460.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_480.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_500.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_520.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_540.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_560.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_580.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_60.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_600.json
#
#
# No errors found in the json file:
# yelp_response_Edmonton Oilers_80.json
#
#
# No errors found in the json file:
# yelp_response_Florida Panthers_0.json
#
#
# No errors found in the json file:
# yelp_response_Florida Panthers_20.json
#
#
# No errors found in the json file:
# yelp_response_Florida Panthers_40.json
#
#
# No errors found in the json file:
# yelp_response_Florida Panthers_60.json
#
#
# No errors found in the json file:
# yelp_response_Florida Panthers_80.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_0.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_100.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_120.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_140.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_160.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_180.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_20.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_200.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_220.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_240.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_260.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_280.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_300.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_320.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_340.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_360.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_380.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_40.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_400.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_420.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_440.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_460.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_480.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_500.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_520.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_540.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_560.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_580.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_60.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_600.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_620.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_640.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_660.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_680.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_700.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_720.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_740.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_760.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_780.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_80.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_800.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_820.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_840.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_860.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_880.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_900.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_920.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_940.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_960.json
#
#
# No errors found in the json file:
# yelp_response_Los Angeles Kings_980.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_0.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_100.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_120.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_140.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_160.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_180.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_20.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_200.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_220.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_240.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_260.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_280.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_40.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_60.json
#
#
# No errors found in the json file:
# yelp_response_Minnesota Wild_80.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_0.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_100.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_120.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_140.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_160.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_180.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_20.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_200.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_220.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_240.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_260.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_280.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_300.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_320.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_340.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_360.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_380.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_40.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_400.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_420.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_440.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_460.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_480.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_500.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_520.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_540.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_560.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_580.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_60.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_600.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_620.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_640.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_660.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_680.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_700.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_720.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_740.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_760.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_780.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_80.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_800.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_820.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_840.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_860.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_880.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_900.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_920.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_940.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_960.json
#
#
# No errors found in the json file:
# yelp_response_Montreal Canadiens_980.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_0.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_100.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_120.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_140.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_160.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_180.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_20.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_200.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_220.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_240.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_260.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_280.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_300.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_320.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_340.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_360.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_380.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_40.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_400.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_420.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_440.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_460.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_480.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_500.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_520.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_540.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_560.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_580.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_60.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_600.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_620.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_640.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_660.json
#
#
# No errors found in the json file:
# yelp_response_Nashville Predators_80.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_0.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_100.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_120.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_140.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_160.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_180.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_20.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_200.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_220.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_240.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_260.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_280.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_300.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_320.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_340.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_360.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_380.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_40.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_400.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_420.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_440.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_460.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_480.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_500.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_520.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_540.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_560.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_60.json
#
#
# No errors found in the json file:
# yelp_response_New Jersey Devils_80.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_0.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_100.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_120.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_140.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_160.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_180.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_20.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_200.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_220.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_240.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_260.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_280.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_40.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_60.json
#
#
# No errors found in the json file:
# yelp_response_New York Islanders_80.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_0.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_100.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_120.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_140.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_160.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_180.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_20.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_200.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_220.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_240.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_260.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_280.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_300.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_320.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_340.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_360.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_380.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_40.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_400.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_420.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_440.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_460.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_480.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_500.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_520.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_540.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_560.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_580.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_60.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_600.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_620.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_640.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_660.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_680.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_700.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_720.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_740.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_760.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_780.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_80.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_800.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_820.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_840.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_860.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_880.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_900.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_920.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_940.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_960.json
#
#
# No errors found in the json file:
# yelp_response_New York Rangers_980.json
#
#
# No errors found in the json file:
# yelp_response_Ottawa Senators_0.json
#
#
# No errors found in the json file:
# yelp_response_Ottawa Senators_20.json
#
#
# No errors found in the json file:
# yelp_response_Ottawa Senators_40.json
#
#
# No errors found in the json file:
# yelp_response_Ottawa Senators_60.json
#
#
# No errors found in the json file:
# yelp_response_Ottawa Senators_80.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_0.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_100.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_120.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_140.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_160.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_180.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_20.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_200.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_220.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_240.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_260.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_280.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_40.json
#
#
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_60.json
# No errors found in the json file:
# yelp_response_Philadelphia Flyers_80.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_0.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_100.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_120.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_140.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_160.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_180.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_20.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_200.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_220.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_240.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_260.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_280.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_300.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_320.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_340.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_360.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_380.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_40.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_400.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_420.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_440.json
#
#
# No errors found in the json file:
# yelp_response_Pittsburgh Penguins_460.json
#
#
# ...
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_40.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_400.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_420.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_440.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_460.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_480.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_500.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_520.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_540.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_560.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_580.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_60.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_600.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_620.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_640.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_660.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_680.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_700.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_720.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_740.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_760.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_780.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_80.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_800.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_820.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_840.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_860.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_880.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_900.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_920.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_940.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_960.json
#
#
# No errors found in the json file:
# yelp_response_Toronto Maple Leafs_980.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_0.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_100.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_120.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_140.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_160.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_180.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_20.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_200.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_220.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_240.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_260.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_280.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_300.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_320.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_340.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_360.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_380.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_40.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_400.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_420.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_440.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_460.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_480.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_500.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_520.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_540.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_560.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_580.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_60.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_600.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_620.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_640.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_660.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_680.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_700.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_720.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_740.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_760.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_780.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_80.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_800.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_820.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_840.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_860.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_880.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_900.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_920.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_940.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_960.json
#
#
# No errors found in the json file:
# yelp_response_Vancouver Canucks_980.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_0.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_100.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_120.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_140.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_160.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_180.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_20.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_200.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_220.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_240.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_260.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_280.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_300.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_320.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_340.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_360.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_380.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_40.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_400.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_420.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_440.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_460.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_480.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_500.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_520.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_540.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_560.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_580.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_60.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_600.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_620.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_640.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_660.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_680.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_700.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_720.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_740.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_760.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_780.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_80.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_800.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_820.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_840.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_860.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_880.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_900.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_920.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_940.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_960.json
#
#
# No errors found in the json file:
# yelp_response_Vegas Golden Knights_980.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_0.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_100.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_120.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_140.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_160.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_180.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_20.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_200.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_220.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_240.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_260.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_280.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_300.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_320.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_340.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_360.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_380.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_40.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_400.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_420.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_440.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_460.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_480.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_500.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_520.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_540.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_560.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_580.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_60.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_600.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_620.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_640.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_660.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_680.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_700.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_720.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_740.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_760.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_780.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_80.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_800.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_820.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_840.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_860.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_880.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_900.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_920.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_940.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_960.json
#
#
# No errors found in the json file:
# yelp_response_Washington Capitals_980.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_0.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_100.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_120.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_140.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_160.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_180.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_20.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_200.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_220.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_240.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_260.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_280.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_300.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_320.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_340.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_360.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_380.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_40.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_400.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_60.json
#
#
# No errors found in the json file:
# yelp_response_Winnipeg Jets_80.json
#
# No erros in json files.
# No files to be removed for the analysis.

# %%
error_list
# Out:
# []

# %% [markdown]
# error_list[0].split('_')[2]

# %%
def tryagain(lista):
    team_errors=[]
    for file in lista:
        aux=file.split("_")[2]
        team_errors.append(aux)
    return team_errors

# %%
team_errors=tryagain(error_list)
team_errors

# %% [markdown]
# ## Try to download again the cities with errors

# %%
newfolder=f'again_for_errors.{today.day}_{today.month}_{today.year}_{today.hour}h{today.minute}m'
newpath=createFolder(newfolder)

# %%
er_df=stadium_df[stadium_df["Team"].isin(team_errors)]

# %%
er_df

# %%
new_list=teamLoc(er_df)

# %%
downloadJSON(new_list, "restaurants", 3000, newpath)

# %%
newerror_list = JSONcheck(newpath)

# %%
newerror_list

# %%
# Check again for errors
error_list2 = JSONcheck(outpath)
